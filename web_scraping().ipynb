# %% [markdown]
# <a href="https://colab.research.google.com/github/hwmishra/andol/blob/master/web_scraping().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
page = requests.get('https://www.parentune.com/baby-names')

# %%
page.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="en">\n<head>\n\n<script>\n(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-N52BBCW\');</script>\n                  <link rel="canonical" href="https://www.parentune.com/baby-names"/>\n    <link rel="amphtml" href="https://www.parentune.com/baby-names?amp=true">\n    \n    <meta charset="utf-8">\n\t<link rel="dns-prefetch" href="//www.parentune.com" />\n    <link rel="dns-prefetch" href="//img1.parentune.com" />\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <title>34294 Latest Newborn Baby Names Ideas, Cute Indian Babynames List, Kids Names with Meaning | Parentune.com</title>\n\n    <meta name="robots" content="index, follow
# ...

# %%
from bs4 import BeautifulSoup

# %%
bs = BeautifulSoup(page.text)

# %%
tables =bs.find_all('table')

# %%
table = tables[0]

# %%
len(table.find_all('tr'))
# Out:
# 21

# %%
trs = table.find_all('tr')

# %%
for th in trs[0].find_all('th'):
    print(th.get_text())
# Out:
#             Gender
#
#
#             Names
#
#
#             Meaning
#
#
#             Favourites

# %%
for tr in trs[1:]:
    td_name =tr.find_all('td')[1]
    td_meaning = tr.find_all('td')[2]td_name.get_text())
    print('meaning:',td_meaning.get
    print('name:',_text())
# Out:
# name:
# A'dab
#
# meaning:
#             the person who brings hope to the family
#
# name:
# A'idah
#
# meaning:
#             Something of value given in return of some thing good, Rewar...
#
# name:
# A'ishah
#
# meaning:
#             the one who is characterized by success  or having favorable...
#
# name:
# Aa'idah
#
# meaning:
#             Name of a female narrator of Hadith.
#
# name:
# Aaaqil
#
# meaning:
#             One who is wise and intelligent.
#
# name:
# Aaarabisk
#
# meaning:
#             A person who is wishful and healthy
#
# name:
# Aaban
#
# meaning:
#             Name of the Angel,  8th Persian month,  angel of iron,  name...
#
# name:
# Aabdar
#
# meaning:
#             Name aabdar has a quranic origin which means Moon light,   e...
#
# name:
# Aabdeen
#
# meaning:
#             Worshipper
#
# name:
# Aabha
#
# meaning:
#             Glow; Splendour; Light; Brilliance; Bright and Radiant; Glor...
#
# name:
# Aabharan
#
# meaning:
# ...

# %%
# <a href="link"></a>

for a in bs.find_all('a', href=True,class_=True):
    print(a['class'])
# Out:
# ['', 'showLoader']
# ['', 'showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['']
# ['']
# ['active']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['', 'showLoader']
# ['genderFilterButton']
# ['genderFilterButton']
# ['originFilterButton']
# ['originFilterButton']
# ['originFilterButton']
# ['originFilterButton']
# ['alphabetFilterButton', 'internal']
# ...
